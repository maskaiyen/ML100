# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = MSE = sum((y - yp)**2)/ len(y)
    return mse

# %%
def mean_absolute_error(y, yp):
    """
    請完成這個 Function 後往下執行
    """
    mae = MAE = sum(abs(y - yp))/ len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 240.278
# The Mean absolute error is 11.984

# %% [markdown]
# ### 作業1：
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# #### Q1. 你選的這組資料為何重要
# A1: 從 Kaggle上選定 Black Friday dataset，銷售是企業的核心問題，如何增加銷售提高營收為企業所關心的議題
#
# #### Q2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# A2: 資料由零售業 ABC Private Limited 所提供，提供上個月購買大宗物品的顧客資料
#
# #### Q3. 蒐集而來的資料型態為何
# A3: 結構化的資料，csv格式，共有 12 個欄位，使用者ID，產品ID，性別，年齡，職業，居住城市，居住幾年，婚姻狀態，產品類別_1，產品類別_2，產品類別_3，購買金額
#
# #### Q4. 這組資料想解決的問題如何評估
# A4: 根據不同的產品預估客戶購買的金額，將採用 MAE 做為衡量方法

# %% [markdown]
# ### 作業2：
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# #### Q1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# A1: 假設穩定的客源來自於搭乘需求，哪些搭乘地點，經常性有乘車需求，則建議計程車司機前往該地點排班
# #### Q2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# A2: 取得客戶訂車的紀錄，包含訂車時間，訂車地點，上車地點，目的地等
# #### Q3. 蒐集而來的資料型態為何
# A3: 結構化的資料，記載每個使用者的訂車紀錄
# #### Q4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# A4: 根據不同的乘車地點，預估每日搭乘計程車金額。採用 MAE 做為衡量方法
